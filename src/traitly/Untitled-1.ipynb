# %%
from traitly.fruit_phenotyping import FruitInternalAnalyzer
path = '/Users/alejandra/Documents/traitly/tests/sample_data/'

test = FruitInternalAnalyzer(path)

test.analyze_folder()
# Out:
# ...
#                                           Traitly running ⋆✧｡٩(ˊᗜˋ )و✧*｡
# ...
#     > Input folder: /Users/alejandra/Documents/traitly/tests/sample_data/
#     > Image(s) detected: 5
#     > analyze_morphology: True
#     > analyze_color: True
#     > num_cores: 1
# Processing images: 100%|██████████| 5/5 [00:03<00:00,  1.28img/s]
# ( ദ്ദി ˙ᗜ˙ ) Finished ===============================================
#     > Image(s) processed:
#         - Successfully: 4/5 img(s)
#         - Errors: 1/5 img(s)
#         - Total fruits: 100
#         - Total time: 4.0s  (avg 0.8s/img)
#     > Files saved:
#         - 4 annotated image(s)
#         - morphology_results.csv
#         - color_results.csv
#         - session_report.txt
#         - error_report.txt
#         - Results folder: /Users/alejandra/Documents/traitly/tests/sample_data/Results

# %%
from traitly.fruit_phenotyping import FruitExternalAnalyzer


path = '/Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test'
json= '/Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/corregida_1-20_parameters.json'
test = FruitExternalAnalyzer(path)
test.analyze_folder(json_path = json)
# Out:
# ...
#                                           Traitly running ⋆✧｡٩(ˊᗜˋ )و✧*｡
# ...
#     > Input folder: /Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test
#     > Image(s) detected: 9
#     > analyze_morphology: True
#     > analyze_color: True
#     > num_cores: 1
#     > Parameters loaded from: /Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/corregida_1-20_parameters.json
# Processing images: 100%|██████████| 9/9 [00:14<00:00,  1.61s/img]
# ( ദ്ദി ˙ᗜ˙ ) Finished ===============================================
#         - Successfully: 8/9 img(s)
#         - Errors: 1/9 img(s)
#         - Total fruits: 254
#         - Total time: 14.5s  (avg 1.6s/img)
#     > Files saved:
#         - 8 annotated image(s)
#         - morphology_results.csv
#         - color_results.csv
#         - session_report.txt
#         - error_report.txt
#         - Results folder: /Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/Results

# %%
from traitly.fruit_phenotyping import FruitExternalAnalyzer

path = '/Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/corregida_1-20.jpg'
test = FruitExternalAnalyzer(path)

test.load_image(plot = False)
test.setup_measurements(verbose =False)
test.generate_fruit_mask(plot = False)
test.detect_fruits(verbose = False)
test.analyze_morphology(display_table = False)
test.analyze_color(plot =False, font_size = 10, display_table = False)

# %%
test.save_parameters()
# Out:
# > Parameters saved:
#   - TXT:  /Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/corregida_1-20_parameters.txt
#   - JSON: /Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/corregida_1-20_parameters.json

# %%
test.save_parameters()
# Out:
# > Parameters saved:
#   - TXT:  /Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/corregida_1-20_parameters.txt
#   - JSON: /Users/alejandra/Downloads/Eric_Samples_Nov_2025/Test/corregida_1-20_parameters.json

# %%
import inspect
from traitly.fruit_phenotyping import FruitExternalAnalyzer
print(inspect.getsource(FruitExternalAnalyzer.analyze_morphology))
# Out:
#     def analyze_morphology(
#         self,
#         # Contour
#         contour_mode: str = 'raw',
#         epsilon: float = 0.001,
#         # Output
#         display_table: bool = True,
#         # Plot
#         plot: bool = True,
#         plot_size: Tuple[int, int] = (10, 10),
#         font_size: float = 1.5,
#         font_thickness: int = 2,
#         font_color: Tuple[int, int, int] = (0, 0, 0),
#         label_position: str = 'top',
#         label_color: Tuple[int, int, int] = (255, 255, 255),
#         # Contour style
#         pericarp_int_color: Tuple[int, int, int] = (0, 240, 240),
#         pericarp_int_thickness: int = 2
#
#     ):
#         """
#         Analyze fruit morphology and optionally display the annotated image.
#
#         Delegates to
#         :meth:`~traitly.fruit_phenotyping.internal_analysis.FruitInternalAnalyzer.analyze_morphology`
#         and removes internal-only columns (locule, pericarp, internal, symmetry)
# ...
